# %%
pip install streamlit-option-menu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.3/829.3 kB 9.6 MB/s eta 0:00:00
# ...

# %%
import pickle
import streamlit as st
from streamlit_option_menu import option_menu
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/multiple disease prediction models .zip.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/destination/folder')

# %%
# loading the saved models
# heart_disease_model=pickle.load(open("C:/Users/LENOVO/.vscode/cli/PYTHON/Multiple Disease Prediction System/saved projects/heart_disease_model.sav","rb"))

# diabetes_model=pickle.load(open("C:/Users/LENOVO/.vscode/cli/PYTHON/Multiple Disease Prediction System/saved projects/diabetes_model.sav","rb",))

# parkinson_model=pickle.load(open("C:/Users/LENOVO/.vscode/cli/PYTHON/Multiple Disease Prediction System/saved projects/parkinsons_model.sav","rb",))

# breastCancer_model=pickle.load(open("C:/Users/LENOVO/.vscode/cli/PYTHON/Multiple Disease Prediction System/saved projects/breast_cancer_model.sav","rb",))
#sidebar for navigate
#     with st.sidebar:C:\Users\LENOVO\Desktop\Multiple Disease Prediction System\saved projects
selected = option_menu(
        "Multiple Disease Prediction System",
        ["Heart disease prediction", "Diabetes prediction", "Parkinsons prediction","Breast Cancer prediction "],
        icons=["heart","activity","person","Clipboard2 pulse"],
        default_index=0
    )
# Heart disease prediction page
if(selected=="Heart disease prediction"):
    # page title
    st.title("Heart disease prediction using ml")
    # getting the_input fro user
    # columns for_input fields
    col1, col2 ,col3 =st.columns(3)
 # age,sex,cp,trestbps,chol,fbs,restecg,thalach,exang,oldpeak,slope,ca,thal,
    with col1:
        age=st.text_input('age')
    with col2:
        sex=st.text_input('sex')
    with col3:
        cp=st.text_input('chest pain types')
    with col1:
        trestbps=st.text_input('Resting Blood pressure')
    with col2:
        chol=st.text_input('serum cholestarol in mg/dl')
    with col3:
        fbs=st.text_input('Fasting Blood sugar>120 mg/dl')
    with col1:
        restecg=st.text_input('resting Electrocardiographic results')
    with col2:
        thalach = st.text_input('Maximum heart rate achived')
    with col3:
        exang=st.text_input('Exercise Induced Angina')
    with col1:
        oldpeak=st.text_input('ST depression induced by exercise')
    with col2:
        slope=st.text_input('Slope of the peak exercise ST segment')
    with col3:
        ca =st.text_input('Major vessels colored by floursopy')
    with col1:
        thal=st.text_input('thal:0=normal;1=fixed defect;2=reversable defect')

    # code for prediction
    heart_diagosis=''

        # creating a button for prediction
    if st.button('Heart Disease Test result'):
        heart_prediction=heart_disease_model.predict([[age,sex,cp,trestbps,chol,fbs,restecg,thalach,exang,oldpeak,slope,ca,thal]])
        if(heart_prediction[0]==1):
            heart_diagosis="The person is having heart disease"
        else:
            heart_diagosis="The person does not have heart disease"

    st.success(heart_diagosis)




# Diabetes prediction page
if(selected=="Diabetes prediction"):
    # page title
    st.title("Diabetes prediction using ml")
    # getting the_input fro user
    # columns for_input fields
    # Pregnancies,Glucose,BloodPressure,SkinThickness,Insulin,BMI,DiabetesPedigreeFunction
    col1, col2 ,col3 =st.columns(3)
    with col1:
        Pregnancies=st.text_input('Number of pregnancie')
    with col2:
        Glucose=st.text_input('Glucose level')
    with col3:
        BloodPressure=st.text_input('Blood Pressure value')
    with col1:
        SkinThickness=st.text_input('Skin Thickness value')
    with col2:
        Insulin=st.text_input('Insulin level')
    with col3:
        BMI=st.text_input('BMI value')
    with col1:
        DiabetesPedigreeFunction=st.text_input('Diabetes Pedigree Function value')
    with col2:
        Age= st.text_input('Age of the person')


    # code for prediction
    diab_dignosis =''

    # creating a button for prediction
    if st.button('Diabetes Test result'):
        diab_prediction = diabetes_model.predict([[Pregnancies,Glucose,BloodPressure,SkinThickness,Insulin,BMI,DiabetesPedigreeFunction,Age]])

        if(diab_prediction[0]==1):
            diab_dignosis='the person is Diabetic'
        else:
            diab_dignosis='The person is not Diabetic'
    st.success(diab_dignosis)



#Parkinsons prediction page
if(selected=="Parkinsons prediction"):
    # page title
    st.title("Parkinsons prediction using ml")
    # getting the_input fro user
    # columns for_input fields
    # name,MDVP:Fo(Hz),MDVP:Fhi(Hz),MDVP:Flo(Hz),MDVP:Jitter(%),MDVP:Jitter(Abs),MDVP:RAP,MDVP:PPQ,Jitter:DDP,MDVP:Shimmer,MDVP:Shimmer(dB),Shimmer:APQ3,Shimmer:APQ5,MDVP:APQ,Shimmer:DDA,NHR,HNR,status,RPDE,DFA,spread1,spread2,D2,PPE

    col1, col2 ,col3,col4,col5 =st.columns(5)
    with col1:
        fo=st.text_input('MDVP:Fo(Hz)')
    with col2:
        fhi=st.text_input('fhi')
    with col3:
        flo=st.text_input('flo')
    with col4:
        jitter_percent=st.text_input('jitter_percent')
    with col5:
        Jitter_Abs=st.text_input('Jitter_Abs')
    with col1:
        RAP=st.text_input('RAP')
    with col2:
        PPQ=st.text_input('PPQ')
    with col3:
        DDP = st.text_input('DDP')
    with col4:
        Shimmer=st.text_input(' Shimmer')
    with col5:
            Shimmer_DB=st.text_input('Shimmer_DB')
    with col1:
        APQ3=st.text_input('APQ3')
    with col2:
        APQ5 = st.text_input('APQ5')
    with col3:
            APQ=st.text_input(' APQ')
    with col4:
        DDA=st.text_input(' DDA')
    with col5:
        NHR=st.text_input('NHR')
    with col1:
        HNR=st.text_input('HNR')
    with col2:
        RPDE = st.text_input('RPDE')
    with col3:
        DFA=st.text_input(' DFA')
    with col4:
        spread1=st.text_input('spread1')
    with col5:
        spread2=st.text_input('spread2')
    with col1:
        D2=st.text_input('D2')
    with col2:
        PPE = st.text_input('pPE')






    # code for prediction
    Parkinsons_diagnosis=''

    # creating a button for parkinsons
    if st.button("Parkinsons Result button"):
        Parkinsons_predicton=parkinson_model.predict([[name,Fo,Fhi,Flo,Jitter,Jitter,RAP,PPQ,DDP,Shimmer,Shimmer,APQ3,APQ5,APQ,DDA,NHR,HNR,status,RPDE,DFA,spread1,spread2,D2,PPE]])

        if(Parkinsons_predicton[0]==1):
            Parkinsons_diagnosis=" The person has parkinson's disease"
        else:
            Parkinsons_diagnosis="The person does not have parkinson's disease"

    st.success(Parkinsons_diagnosis)

    # BreastCancer prediction page
    if(selected=="Parkinsons prediction"):
        # page title
        st.title("Parkinsons prediction using ml")
        #getting the_input fro user
        # columns for_input fields
        # "id","diagnosis","radius_mean","texture_mean","perimeter_mean","area_mean","smoothness_mean","compactness_mean","concavity_mean","concave points_mean","symmetry_mean","fractal_dimension_mean","radius_se","texture_se","perimeter_se","area_se","smoothness_se","compactness_se","concavity_se","concave points_se","symmetry_se","fractal_dimension_se","radius_worst","texture_worst","perimeter_worst","area_worst","smoothness_worst","compactness_worst","concavity_worst","concave points_worst","symmetry_worst","fractal_dimension_worst",



    with col6:
        radius_mean = st.text_input('Mean radius of the tumor')
    with col1:
        texture_mean = st.text_input('Mean texture (gray-scale variation) of the tumor')
    with col2:
        perimeter_mean = st.text_input('Mean perimeter of the tumor')
    with col3:
        area_mean = st.text_input('Mean area of the tumor')
    with col4:
        smoothness_mean = st.text_input('Mean smoothness (edge smoothness) of the tumor')
    with col5:
        compactness_mean = st.text_input('Mean compactness (perimeter² / area) of the tumor')

# Additional inputs for other features
    with col1:
        concavity_mean = st.text_input('Mean concavity (depth of indentations) of the tumor')
    with col2:
        concave_points_mean = st.text_input('Mean number of concave points on the tumor')
    with col3:
        symmetry_mean = st.text_input('Mean symmetry of the tumor')
    with col4:
        fractal_dimension_mean = st.text_input('Mean fractal dimension (complexity) of the tumor')

# Inputs for standard errors
    with col1:
        radius_se = st.text_input('Standard error of the radius')
    with col2:
        texture_se = st.text_input('Standard error of the texture')
    with col3:
        perimeter_se = st.text_input('Standard error of the perimeter')
    with col4:
        area_se = st.text_input('Standard error of the area')
    with col5:
        smoothness_se = st.text_input('Standard error of the smoothness')
    with col6:
        compactness_se = st.text_input('Standard error of the compactness')

# More standard error inputs
    with col1:
        concavity_se = st.text_input('Standard error of the concavity')
    with col2:
        concave_points_se = st.text_input('Standard error of the concave points')
    with col3:
        symmetry_se = st.text_input('Standard error of the symmetry')
    with col4:
        fractal_dimension_se = st.text_input('Standard error of the fractal dimension')

# Inputs for the worst values
    with col1:
        radius_worst = st.text_input('Worst (largest) radius of the tumor')
    with col2:
        texture_worst = st.text_input('Worst (highest) variation in texture')
    with col3:
        perimeter_worst = st.text_input('Worst (largest) perimeter of the tumor')
    with col4:
        area_worst = st.text_input('Worst (largest) area of the tumor')
    with col5:
        smoothness_worst = st.text_input('Worst (least smooth) edge of the tumor')
    with col6:
        compactness_worst = st.text_input('Worst (highest) compactness of the tumor')

# More inputs for worst values
    with col1:
        concavity_worst = st.text_input('Worst (deepest) concavity of the tumor')
    with col2:
        concave_points_worst = st.text_input('Worst (most concave) points on the tumor edge')
    with col3:
        symmetry_worst = st.text_input('Worst (most asymmetrical) symmetry of the tumor')
    with col4:
        fractal_dimension_worst = st.text_input('Worst (most complex) fractal dimension of the tumor')

    # code for prediction
    BreastCancer_diagnosis=''

    # creating a bottun for Breast Cancer
    if st.button("Breast Cancer result button"):
        BreastCancer_prediction = breastCancer_model.predict([[
    radius_mean, texture_mean, perimeter_mean, area_mean,
    smoothness_mean, compactness_mean, concavity_mean, concave_points_mean,
    symmetry_mean, fractal_dimension_mean, radius_se, texture_se, perimeter_se, area_se,
    smoothness_se, compactness_se, concavity_se, concave_points_se,
    symmetry_se, fractal_dimension_se, radius_worst, texture_worst,
    perimeter_worst, area_worst, smoothness_worst, compactness_worst,
    concavity_worst, concave_points_worst, symmetry_worst, fractal_dimension_worst
]])


        if(BreastCancer_prediction[0]==0):
            BreastCancer_diagnosis=" The person have cancer"
        else:
            BreastCancer_diagnosis="The person have not cancer"

    st.success(BreastCancer_diagnosis)
# Out:
# 2025-04-21 06:10:30.437 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 06:10:30.438 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 06:10:30.440 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 06:10:30.538
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-04-21 06:10:30.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 06:10:30.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
